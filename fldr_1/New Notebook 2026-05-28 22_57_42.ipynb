# %%
df = spark.read.format("jdbc") \
    .option("url", "jdbc:sqlserver://17.0.1000.7:1433;databaseName=DemoDB") \
    .option("dbtable", "dbo.Employee") \
    .option("user", "sa") \
    .option("password", "riya@123") \
    .option("driver", "com.microsoft.sqlserver.jdbc.SQLServerDriver") \
    .load()

display(df)
